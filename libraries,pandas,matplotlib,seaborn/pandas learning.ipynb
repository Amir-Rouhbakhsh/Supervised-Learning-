# %%
import pandas as pd

# %% [markdown]
# create series

# %%
myindex=['ali', 'iman']
mydata= [190, 180]
myserie=pd.Series(mydata, myindex)
myserie
# Out:
# ali     190
# iman    180
# dtype: int64

# %%
myserie['ali']
# Out:
# 190

# %%
myserie[0]
# Out:
# 190

# %% [markdown]
# Dictionary

# %%
myage={'ali':23 ,'iman':30}
age=pd.Series(myage)

# %%
age.keys()
# Out:
# Index(['ali', 'iman'], dtype='object')

# %% [markdown]
# dataframe

# %%
import numpy as np 
np.random.seed(101)
data= np.random.randint(0,101, (4,3))
data
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
row=['ali', 'iman', 'ahmad', 'ziba']
col= ["age", "height", 'weight']
df=pd.DataFrame(data,row,col)
df
# Out:
#        age  height  weight
# ali     95      11      81
# iman    70      63      87
# ahmad   75       9      77
# ziba    40       4      63

# %% [markdown]
# read csv files

# %%
df1=pd.read_csv(r'HousePrice.csv')
df1
# Out:
#       Unnamed: 0  Room  Parking  Warehouse  Elevator             Address  \
# 0              0     1     True       True      True             Shahran
# 1              1     1     True       True      True             Shahran
# 2              2     2     True       True      True              Pardis
# 3              3     2     True       True      True       Shahrake Qods
# 4              4     2     True       True      True      Shahrake Gharb
# ...          ...   ...      ...        ...       ...                 ...
# 3474        3474     2     True       True      True  Southern Janatabad
# 3475        3475     2     True       True      True            Niavaran
# 3476        3476     2    False      False     False              Parand
# 3477        3477     2     True       True      True              Dorous
# 3478        3478     2    False       True      True              Parand
#
#              Price  Price(USD)   area
# 0     1.850000e+09    61666.67   63.0
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0  Room  Parking  Warehouse  Elevator         Address  \
# 0           0     1     True       True      True         Shahran
# 1           1     1     True       True      True         Shahran
# 2           2     2     True       True      True          Pardis
# 3           3     2     True       True      True   Shahrake Qods
# 4           4     2     True       True      True  Shahrake Gharb
#
#           Price  Price(USD)   area
# 0  1.850000e+09    61666.67   63.0
# 1  1.850000e+09    61666.67   60.0
# 2  5.500000e+08    18333.33   79.0
# 3  9.025000e+08    30083.33   95.0
# 4  7.000000e+09   233333.33  123.0

# %%
df1.head(20)
# Out:
#     Unnamed: 0  Room  Parking  Warehouse  Elevator  \
# 0            0     1     True       True      True
# 1            1     1     True       True      True
# 2            2     2     True       True      True
# 3            3     2     True       True      True
# 4            4     2     True       True      True
# 5            5     2     True       True     False
# 6            6     2     True       True      True
# 7            7     1     True       True      True
# 8            8     2     True       True     False
# 9            9     1     True       True      True
# 10          10     2     True       True      True
# 11          11     1     True       True      True
# 12          12     1    False       True      True
# 13          13     3     True       True      True
# 14          14     2     True       True      True
# 15          15     1    False       True     False
# 16          16     3     True       True      True
# ...

# %%
df1.tail()
# Out:
#       Unnamed: 0  Room  Parking  Warehouse  Elevator             Address  \
# 3474        3474     2     True       True      True  Southern Janatabad
# 3475        3475     2     True       True      True            Niavaran
# 3476        3476     2    False      False     False              Parand
# 3477        3477     2     True       True      True              Dorous
# 3478        3478     2    False       True      True              Parand
#
#              Price  Price(USD)   area
# 3474  3.500000e+09   116666.67   86.0
# 3475  6.800000e+09   226666.67   83.0
# 3476  3.650000e+08    12166.67   75.0
# 3477  5.600000e+09   186666.67  105.0
# 3478  3.600000e+08    12000.00   82.0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3479 non-null   int64
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   float64
#  7   Price(USD)  3479 non-null   float64
#  8   area        3473 non-null   float64
# dtypes: bool(3), float64(3), int64(2), object(1)
# memory usage: 173.4+ KB

# %%
df1.describe()
# Out:
#        Unnamed: 0         Room         Price    Price(USD)         area
# count  3479.00000  3479.000000  3.479000e+03  3.479000e+03  3473.000000
# mean   1739.00000     2.079908  5.359023e+09  1.786341e+05   106.774547
# std    1004.44512     0.758275  8.099935e+09  2.699978e+05    69.365567
# min       0.00000     0.000000  3.600000e+06  1.200000e+02    30.000000
# 25%     869.50000     2.000000  1.418250e+09  4.727500e+04    69.000000
# 50%    1739.00000     2.000000  2.900000e+09  9.666667e+04    90.000000
# 75%    2608.50000     2.000000  6.000000e+09  2.000000e+05   120.000000
# max    3478.00000     5.000000  9.240000e+10  3.080000e+06   929.000000

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Room', 'Parking', 'Warehouse', 'Elevator', 'Address',
#        'Price', 'Price(USD)', 'area'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=3479, step=1)

# %%
df1['Address']
# Out:
# 0                  Shahran
# 1                  Shahran
# 2                   Pardis
# 3            Shahrake Qods
# 4           Shahrake Gharb
#                ...
# 3474    Southern Janatabad
# 3475              Niavaran
# 3476                Parand
# 3477                Dorous
# 3478                Parand
# Name: Address, Length: 3479, dtype: object

# %%
df1[['Address', 'area']]
# Out:
#                  Address   area
# 0                Shahran   63.0
# 1                Shahran   60.0
# 2                 Pardis   79.0
# 3          Shahrake Qods   95.0
# 4         Shahrake Gharb  123.0
# ...                  ...    ...
# 3474  Southern Janatabad   86.0
# 3475            Niavaran   83.0
# 3476              Parand   75.0
# 3477              Dorous  105.0
# 3478              Parand   82.0
#
# [3479 rows x 2 columns]

# %% [markdown]
# creating a new df derived from the old one

# %%
newDF= df1[['Address', 'area']]
newDF
# Out:
#                  Address   area
# 0                Shahran   63.0
# 1                Shahran   60.0
# 2                 Pardis   79.0
# 3          Shahrake Qods   95.0
# 4         Shahrake Gharb  123.0
# ...                  ...    ...
# 3474  Southern Janatabad   86.0
# 3475            Niavaran   83.0
# 3476              Parand   75.0
# 3477              Dorous  105.0
# 3478              Parand   82.0
#
# [3479 rows x 2 columns]

# %% [markdown]
# removing the column and row    column  axis =1  row   axis =0

# %%
df2=df1.drop('Room', axis=1)
df2
# Out:
#       Unnamed: 0  Parking  Warehouse  Elevator             Address  \
# 0              0     True       True      True             Shahran
# 1              1     True       True      True             Shahran
# 2              2     True       True      True              Pardis
# 3              3     True       True      True       Shahrake Qods
# 4              4     True       True      True      Shahrake Gharb
# ...          ...      ...        ...       ...                 ...
# 3474        3474     True       True      True  Southern Janatabad
# 3475        3475     True       True      True            Niavaran
# 3476        3476    False      False     False              Parand
# 3477        3477     True       True      True              Dorous
# 3478        3478    False       True      True              Parand
#
#              Price  Price(USD)   area
# 0     1.850000e+09    61666.67   63.0
# 1     1.850000e+09    61666.67   60.0
# 2     5.500000e+08    18333.33   79.0
# ...

# %% [markdown]
# iloc    return the value of one row or a range of rows

# %%
df1.iloc[10]             # return the value of row 10th
# Out:
# Unnamed: 0                        10
# Room                               2
# Parking                         True
# Warehouse                       True
# Elevator                        True
# Address       West Ferdows Boulevard
# Price                   2450000000.0
# Price(USD)                  81666.67
# area                            68.0
# Name: 10, dtype: object

# %%
df1.iloc[5:15]
# Out:
#     Unnamed: 0  Room  Parking  Warehouse  Elevator  \
# 5            5     2     True       True     False
# 6            6     2     True       True      True
# 7            7     1     True       True      True
# 8            8     2     True       True     False
# 9            9     1     True       True      True
# 10          10     2     True       True      True
# 11          11     1     True       True      True
# 12          12     1    False       True      True
# 13          13     3     True       True      True
# 14          14     2     True       True      True
#
#                        Address         Price  Price(USD)   area
# 5   North Program Organization  2.050000e+09    68333.33   70.0
# 6                       Pardis  6.000000e+08    20000.00   87.0
# 7                      Shahran  2.150000e+09    71666.67   59.0
# 8                     Andisheh  4.930000e+08    16433.33   54.0
# 9       West Ferdows Boulevard  2.370000e+09    79000.00   71.0
# ...

# %%
df
# Out:
#        age  height  weight
# ali     95      11      81
# iman    70      63      87
# ahmad   75       9      77
# ziba    40       4      63

# %% [markdown]
# loc  is used insted of iloc when the rows are not numbers

# %%
df.loc['ali']
# Out:
# age       95
# height    11
# weight    81
# Name: ali, dtype: int32

# %%
df.loc[['ali', 'iman']]
# Out:
#       age  height  weight
# ali    95      11      81
# iman   70      63      87

# %%
df1
# Out:
#       Unnamed: 0  Room  Parking  Warehouse  Elevator             Address  \
# 0              0     1     True       True      True             Shahran
# 1              1     1     True       True      True             Shahran
# 2              2     2     True       True      True              Pardis
# 3              3     2     True       True      True       Shahrake Qods
# 4              4     2     True       True      True      Shahrake Gharb
# ...          ...   ...      ...        ...       ...                 ...
# 3474        3474     2     True       True      True  Southern Janatabad
# 3475        3475     2     True       True      True            Niavaran
# 3476        3476     2    False      False     False              Parand
# 3477        3477     2     True       True      True              Dorous
# 3478        3478     2    False       True      True              Parand
#
#              Price  Price(USD)   area
# 0     1.850000e+09    61666.67   63.0
# ...

# %% [markdown]
# conditional filtering

# %%
df1['Room']>2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3474    False
# 3475    False
# 3476    False
# 3477    False
# 3478    False
# Name: Room, Length: 3479, dtype: bool

# %%
df1[df1['Room']>2]
# Out:
#       Unnamed: 0  Room  Parking  Warehouse  Elevator                 Address  \
# 13            13     3     True       True      True             Saadat Abad
# 16            16     3     True       True      True                  Narmak
# 18            18     3     True       True      True  West Ferdows Boulevard
# 25            25     3     True       True      True                Velenjak
# 44            44     3     True       True     False                ShahrAra
# ...          ...   ...      ...        ...       ...                     ...
# 3453        3453     3     True       True     False               Marzdaran
# 3457        3457     3     True       True      True                Velenjak
# 3458        3458     3     True       True      True               Daryan No
# 3463        3463     3     True      False      True          Shahrake Gharb
# 3472        3472     3     True       True      True             Ostad Moein
#
#              Price  Price(USD)   area
# ...

# %%
df1[df1['Address']=='Shahrake Gharb']
# Out:
#       Unnamed: 0  Room  Parking  Warehouse  Elevator         Address  \
# 4              4     2     True       True      True  Shahrake Gharb
# 20            20     2     True       True      True  Shahrake Gharb
# 47            47     3     True       True     False  Shahrake Gharb
# 211          211     2     True       True      True  Shahrake Gharb
# 227          227     3     True       True      True  Shahrake Gharb
# 228          228     2     True       True      True  Shahrake Gharb
# 271          271     3     True       True      True  Shahrake Gharb
# 344          344     2     True       True      True  Shahrake Gharb
# 602          602     3     True       True      True  Shahrake Gharb
# 607          607     2     True       True      True  Shahrake Gharb
# 610          610     2     True       True      True  Shahrake Gharb
# 611          611     3     True       True      True  Shahrake Gharb
# 649          649     2     True       True      True  Shahrake Gharb
# ...

# %%
df1[ (df1['Room']>2) & (df1['Address']=='Shahrake Gharb')]
# Out:
#       Unnamed: 0  Room  Parking  Warehouse  Elevator         Address  \
# 47            47     3     True       True     False  Shahrake Gharb
# 227          227     3     True       True      True  Shahrake Gharb
# 271          271     3     True       True      True  Shahrake Gharb
# 602          602     3     True       True      True  Shahrake Gharb
# 611          611     3     True       True      True  Shahrake Gharb
# 650          650     3     True       True      True  Shahrake Gharb
# 699          699     3     True       True      True  Shahrake Gharb
# 775          775     3     True       True      True  Shahrake Gharb
# 842          842     3     True       True      True  Shahrake Gharb
# 850          850     3     True       True      True  Shahrake Gharb
# 860          860     3     True       True      True  Shahrake Gharb
# 863          863     3     True       True      True  Shahrake Gharb
# 1033        1033     3     True       True      True  Shahrake Gharb
# ...

# %%
df1[df1['area'].isin([120,140])]                     ##  area is 120 or 140
# Out:
#       Unnamed: 0  Room  Parking  Warehouse  Elevator                 Address  \
# 18            18     3     True       True      True  West Ferdows Boulevard
# 87            87     1    False      False     False                Shahryar
# 95            95     3     True       True      True                  Rudhen
# 115          115     3     True       True      True                   Gisha
# 120          120     3     True       True      True                  Fatemi
# ...          ...   ...      ...        ...       ...                     ...
# 3315        3315     2     True       True      True                     NaN
# 3374        3374     2     True       True      True                Niavaran
# 3436        3436     3     True       True      True               Daryan No
# 3439        3439     3     True       True      True                  Mehran
# 3444        3444     3     True       True      True              Sattarkhan
#
#              Price  Price(USD)   area
# ...

# %%
df2= pd.read_csv(r'audi.csv')
df2
# Out:
#     Model    Year  Price Transmission  Mileage FuelType  EngineSize
# 0      A1  2017.0  12500       Manual      NaN   Petrol         NaN
# 1      A6  2016.0  16500    Automatic  36203.0   Diesel         2.0
# 2      A1  2016.0  11000          NaN  29946.0   Petrol         1.4
# 3      A4  2017.0  16800    Automatic  25952.0   Diesel         2.0
# 4      A3  2019.0  17300       Manual   1998.0   Petrol         1.0
# ..    ...     ...    ...          ...      ...      ...         ...
# 194    A4     NaN  30985    Automatic  21009.0   Petrol         3.0
# 195    A6  2019.0  29985    Automatic   1881.0   Diesel         2.0
# 196    A6  2019.0  27985          NaN      NaN      NaN         NaN
# 197    A6  2019.0  30985    Automatic   1863.0   Diesel         2.0
# 198    Q7  2020.0  62985    Semi-Auto     10.0   Diesel         NaN
#
# [199 rows x 7 columns]

# %% [markdown]
# Missing data     df.isnull()      True = we have NAN or missing data

# %%
df2.isnull()
# Out:
#      Model   Year  Price  Transmission  Mileage  FuelType  EngineSize
# 0    False  False  False         False     True     False        True
# 1    False  False  False         False    False     False       False
# 2    False  False  False          True    False     False       False
# 3    False  False  False         False    False     False       False
# 4    False  False  False         False    False     False       False
# ..     ...    ...    ...           ...      ...       ...         ...
# 194  False   True  False         False    False     False       False
# 195  False  False  False         False    False     False       False
# 196  False  False  False          True     True      True        True
# 197  False  False  False         False    False     False       False
# 198  False  False  False         False    False     False        True
#
# [199 rows x 7 columns]

# %% [markdown]
# Removing missing data from dataframe

# %%
newdf= df2.dropna()
newdf
# Out:
#     Model    Year  Price Transmission  Mileage FuelType  EngineSize
# 1      A6  2016.0  16500    Automatic  36203.0   Diesel         2.0
# 3      A4  2017.0  16800    Automatic  25952.0   Diesel         2.0
# 4      A3  2019.0  17300       Manual   1998.0   Petrol         1.0
# 5      A1  2016.0  13900    Automatic  32260.0   Petrol         1.4
# 6      A6  2016.0  13250    Automatic  76788.0   Diesel         2.0
# ..    ...     ...    ...          ...      ...      ...         ...
# 191    A3  2019.0  17985       Manual   8449.0   Diesel         1.6
# 192    A5  2017.0  20485       Manual  34679.0   Diesel         2.0
# 193    A3  2018.0  16985    Semi-Auto  23860.0   Petrol         1.0
# 195    A6  2019.0  29985    Automatic   1881.0   Diesel         2.0
# 197    A6  2019.0  30985    Automatic   1863.0   Diesel         2.0
#
# [187 rows x 7 columns]

# %%
newdf.reset_index(drop=True , inplace=True)                     # index correction asfter removing NAN
newdf
# Out:
#     Model    Year  Price Transmission  Mileage FuelType  EngineSize
# 0      A6  2016.0  16500    Automatic  36203.0   Diesel         2.0
# 1      A4  2017.0  16800    Automatic  25952.0   Diesel         2.0
# 2      A3  2019.0  17300       Manual   1998.0   Petrol         1.0
# 3      A1  2016.0  13900    Automatic  32260.0   Petrol         1.4
# 4      A6  2016.0  13250    Automatic  76788.0   Diesel         2.0
# ..    ...     ...    ...          ...      ...      ...         ...
# 182    A3  2019.0  17985       Manual   8449.0   Diesel         1.6
# 183    A5  2017.0  20485       Manual  34679.0   Diesel         2.0
# 184    A3  2018.0  16985    Semi-Auto  23860.0   Petrol         1.0
# 185    A6  2019.0  29985    Automatic   1881.0   Diesel         2.0
# 186    A6  2019.0  30985    Automatic   1863.0   Diesel         2.0
#
# [187 rows x 7 columns]

# %%
newdf1= df2.dropna(thresh=4, axis=0 )
"""  
thresh , if the non-Nan parameters in one row is equal to thresh do not remove that row ,although there is a NAN parameter in that row 
for instance in the above code if non-NAN parameter is equal or more than 4 do not remove the row 
axis= 0   remove the row      axis =1   remove the column 
subset=[]     put the name of indexes and  dropna will remove NAN parameters in given indexes not the whole dataframe

"""
newdf1
# Out:
#     Model    Year  Price Transmission  Mileage FuelType  EngineSize
# 0      A1  2017.0  12500       Manual      NaN   Petrol         NaN
# 1      A6  2016.0  16500    Automatic  36203.0   Diesel         2.0
# 2      A1  2016.0  11000          NaN  29946.0   Petrol         1.4
# 3      A4  2017.0  16800    Automatic  25952.0   Diesel         2.0
# 4      A3  2019.0  17300       Manual   1998.0   Petrol         1.0
# ..    ...     ...    ...          ...      ...      ...         ...
# 193    A3  2018.0  16985    Semi-Auto  23860.0   Petrol         1.0
# 194    A4     NaN  30985    Automatic  21009.0   Petrol         3.0
# 195    A6  2019.0  29985    Automatic   1881.0   Diesel         2.0
# 197    A6  2019.0  30985    Automatic   1863.0   Diesel         2.0
# 198    Q7  2020.0  62985    Semi-Auto     10.0   Diesel         NaN
#
# [198 rows x 7 columns]

# %% [markdown]
# Replacing the NAN value by other values

# %%
newdf3=df2[df2['Model']==' A1']
newdf3
# Out:
#     Model    Year  Price Transmission  Mileage FuelType  EngineSize
# 0      A1  2017.0  12500       Manual      NaN   Petrol         NaN
# 2      A1  2016.0  11000          NaN  29946.0   Petrol         1.4
# 5      A1  2016.0  13900    Automatic  32260.0   Petrol         1.4
# 9      A1  2016.0  12000       Manual  22451.0   Petrol         NaN
# 27     A1  2018.0  15800       Manual  10793.0   Petrol         NaN
# 30     A1  2015.0   9500    Automatic  54754.0   Diesel         NaN
# 36     A1  2017.0  10800       Manual  31447.0   Petrol         NaN
# 57     A1  2014.0  11000       Manual  34315.0   Petrol         NaN
# 60     A1  2013.0   7000       Manual  76269.0   Diesel         NaN
# 67     A1  2017.0  11700       Manual  19268.0   Petrol         NaN
# 69     A1  2016.0  10800       Manual  18181.0   Petrol         1.0
# 84     A1  2017.0  11300       Manual  29327.0   Petrol         1.4
# 86     A1  2014.0  10000       Manual  28324.0   Petrol         1.4
# ...

# %%
newdf3['EngineSize'].value_counts()
# Out:
# 1.4    11
# 1.0     6
# 1.6     4
# Name: EngineSize, dtype: int64

# %%
newdf4= newdf3['EngineSize'].fillna(1.4)
print(newdf4)
# Out:
# 0      1.4
# 2      1.4
# 5      1.4
# 9      1.4
# 27     1.4
# 30     1.4
# 36     1.4
# 57     1.4
# 60     1.4
# 67     1.4
# 69     1.0
# 84     1.4
# 86     1.4
# 87     1.4
# 89     1.4
# 94     1.4
# 96     1.6
# 110    1.0
# 117    1.6
# 121    1.4
# 122    1.6
# 133    1.0
# 142    1.0
# 143    1.4
# 152    1.4
# 158    1.0
# 163    1.0
# 180    1.4
# 186    1.6
# Name: EngineSize, dtype: float64

# %% [markdown]
# Cancatanation of two Dataframes

# %%
data1= {'A1':['A0', 'A1'] ,'B1': ['B0', 'B1']}
data2= {'C1':['C0', 'C1'] ,'D1': ['D0', 'D1']}

# %%
one=pd.DataFrame(data1)
two= pd.DataFrame(data2)
pd.concat([one,two],axis=1)
# Out:
#    A1  B1  C1  D1
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1

# %%
data2= {'A1':['C0', 'C1'] ,'B1': ['D0', 'D1']}
two= pd.DataFrame(data2)
mydf=pd.concat([one,two],axis=0)
mydf
# Out:
#    A1  B1
# 0  A0  B0
# 1  A1  B1
# 0  C0  D0
# 1  C1  D1

# %%
mydf.index=range(len(mydf))
mydf
# Out:
#    A1  B1
# 0  A0  B0
# 1  A1  B1
# 2  C0  D0
# 3  C1  D1

# %% [markdown]
# merge two Dataframes      inner  left   right   outer merging

# %%
math =pd.DataFrame( {'std-num':[1,2,3,4,5], 'names':['ali', 'ahmad', 'iman', 'amir', 'sadra'] })
physics =pd.DataFrame( {'std-num':[1,2,3,4,5], 'names':['kamran', 'ahmad', 'hassan', 'amir', 'sadra'] })
math , physics
# Out:
# (   std-num  names
#  0        1    ali
#  1        2  ahmad
#  2        3   iman
#  3        4   amir
#  4        5  sadra,
#     std-num   names
#  0        1  kamran
#  1        2   ahmad
#  2        3  hassan
#  3        4    amir
#  4        5   sadra)

# %%
pd.merge(math, physics, how='inner', on='names')           # only mergy those common names between dataframes
# Out:
#    std-num_x  names  std-num_y
# 0          2  ahmad          2
# 1          4   amir          4
# 2          5  sadra          5

# %%
pd.merge(math, physics, how='left', on='names')
# Out:
#    std-num_x  names  std-num_y
# 0          1    ali        NaN
# 1          2  ahmad        2.0
# 2          3   iman        NaN
# 3          4   amir        4.0
# 4          5  sadra        5.0

# %%
pd.merge(math, physics, how='right', on='names')
# Out:
#    std-num_x   names  std-num_y
# 0        NaN  kamran          1
# 1        2.0   ahmad          2
# 2        NaN  hassan          3
# 3        4.0    amir          4
# 4        5.0   sadra          5

# %%
pd.merge(math, physics, how='outer', on='names')
# Out:
#    std-num_x   names  std-num_y
# 0        1.0     ali        NaN
# 1        2.0   ahmad        2.0
# 2        3.0    iman        NaN
# 3        4.0    amir        4.0
# 4        5.0   sadra        5.0
# 5        NaN  kamran        1.0
# 6        NaN  hassan        3.0
